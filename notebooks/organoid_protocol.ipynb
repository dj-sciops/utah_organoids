# %%
import os 
if os.path.basename(os.getcwd()) == "notebooks": os.chdir("..")
import datajoint as dj
from workflow import lineage, induction
# Out:
# [2022-12-28 18:42:55,246][INFO]: Connecting kabilar@rds.datajoint.io:3306
# [2022-12-28 18:42:55,590][INFO]: Connected kabilar@rds.datajoint.io:3306

# %%
dj.Diagram(lineage) + dj.Diagram(induction)
